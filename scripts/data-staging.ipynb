# %%
import pandas as pd
from db import engine
from sqlalchemy import text

# %%
cust = pd.read_csv('../data/olist_customers_dataset.csv')
order = pd.read_csv('../data/olist_orders_dataset.csv')
products = pd.read_csv('../data/olist_products_dataset.csv')
payments = pd.read_csv('../data/olist_order_payments_dataset.csv')
items = pd.read_csv('../data/olist_order_items_dataset.csv')
order_reviews = pd.read_csv('../data/olist_order_reviews_dataset.csv')
sellers = pd.read_csv('../data/olist_customers_dataset.csv')

# %%
cust.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
### partie recuperation des données
cust.to_sql('customers', engine)
order.to_sql('orders', engine)
order_reviews.to_sql('order_reviews', engine)
items.to_sql('items', engine)
payments.to_sql('payments', engine)
sellers.to_sql('sellers', engine)
products.to_sql('products', engine)
# Out:
# 951

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File C:\Projet\DATA ENGiNEERING\1-DataWarehousing\.venv\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File C:\Projet\DATA ENGiNEERING\1-DataWarehousing\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)   3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File C:\Projet\DATA ENGiNEERING\1-DataWarehousing\.venv\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
# ...
